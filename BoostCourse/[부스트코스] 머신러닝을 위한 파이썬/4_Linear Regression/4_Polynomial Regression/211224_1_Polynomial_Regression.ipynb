# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Dataset

# %%
def f(size):
    x = np.linspace(0, 5, size)
    y = x * np.sin(x ** 2) + 1
    return (x,y)

def sample(size):
    x = np.linspace(0, 5, size)
    y = x * np.sin(x ** 2) + 1 + np.random.randn(x.size)*0.5
    return (x,y)

# %%
f_x, f_y = f(1000)
plt.plot(f_x, f_y)
X, y = sample(1000)
plt.scatter(X, y, s=3, c="black")
plt.show()

# %%
X.shape, y.shape
# Out:
# ((1000,), (1000,))

# %%
X = X.reshape(-1, 1)
y = y.reshape(-1, 1)
X.shape, y.shape
# Out:
# ((1000, 1), (1000, 1))

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X,y)
# Out:
# LinearRegression()

# %%
f_x, f_y = f(1000)
plt.plot(f_x, f_y)
plt.scatter(X.flatten(), y.flatten(), s=3, c="black")
plt.plot(X.flatten(), lr.predict(X).flatten())
plt.show()

# %% [markdown]
# # Polynomial Regression

# %%
from sklearn.preprocessing import PolynomialFeatures

poly_features = PolynomialFeatures(degree=2)
X_poly = poly_features.fit_transform(X)
X_poly[:10]
# Out:
# array([[1.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [1.00000000e+00, 5.00500501e-03, 2.50500751e-05],
#        [1.00000000e+00, 1.00100100e-02, 1.00200300e-04],
#        [1.00000000e+00, 1.50150150e-02, 2.25450676e-04],
#        [1.00000000e+00, 2.00200200e-02, 4.00801202e-04],
#        [1.00000000e+00, 2.50250250e-02, 6.26251878e-04],
#        [1.00000000e+00, 3.00300300e-02, 9.01802704e-04],
#        [1.00000000e+00, 3.50350350e-02, 1.22745368e-03],
#        [1.00000000e+00, 4.00400400e-02, 1.60320481e-03],
#        [1.00000000e+00, 4.50450450e-02, 2.02905608e-03]])

# %%
lr = LinearRegression(fit_intercept = False)
lr.fit(X_poly,y)
# Out:
# LinearRegression(fit_intercept=False)

# %%
f_x, f_y = f(1000)
plt.plot(f_x, f_y)
plt.scatter(X.flatten(), y.flatten(), s=3, c="black")
plt.plot(X.flatten(), lr.predict(X_poly).flatten())
plt.show()

# %%
poly_features = PolynomialFeatures(degree=16)
X_poly = poly_features.fit_transform(X)
X_poly[:3]
# Out:
# array([[1.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00],
#        [1.00000000e+00, 5.00500501e-03, 2.50500751e-05, 1.25375751e-07,
#         6.27506263e-10, 3.14067198e-12, 1.57190790e-14, 7.86740691e-17,
#         3.93764110e-19, 1.97079134e-21, 9.86382051e-24, 4.93684710e-26,
#         2.47089445e-28, 1.23668391e-30, 6.18960915e-33, 3.09790248e-35,
#         1.55050174e-37],
#        [1.00000000e+00, 1.00100100e-02, 1.00200300e-04, 1.00300601e-06,
#         1.00401002e-08, 1.00501504e-10, 1.00602106e-12, 1.00702808e-14,
#         1.00803612e-16, 1.00904517e-18, 1.01005522e-20, 1.01106629e-22,
#         1.01207837e-24, 1.01309146e-26, 1.01410556e-28, 1.01512068e-30,
#         1.01613682e-32]])

# %%
lr = LinearRegression(fit_intercept = False)
lr.fit(X_poly,y)
f_x, f_y = f(1000)
plt.plot(f_x, f_y)
plt.scatter(X.flatten(), y.flatten(), s=3, c="black")
plt.plot(X.flatten(), lr.predict(X_poly).flatten())
plt.show()

# %%
def rmse(predictions, targets):
    return np.sqrt(((predictions - targets) ** 2).mean())

# %%
poly_range = list(range(10, 50))
rmse_lr_list = []
rmse_lasso_list = []
rmse_ridge_list = []

from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge

for poly_value in poly_range:
    poly_features = PolynomialFeatures(degree=poly_value)
    X_poly = poly_features.fit_transform(X)
    lr = LinearRegression(fit_intercept = False)
    lr.fit(X_poly,y)
    
    rmse_lr_list.append(rmse(lr.predict(X_poly), y))

    lasso = Lasso(fit_intercept = False)
    lasso.fit(X_poly,y)
    rmse_lasso_list.append(rmse(lasso.predict(X_poly), y))
    
    ridge = Ridge(fit_intercept = False)
    ridge.fit(X_poly,y)
    rmse_ridge_list.append(rmse(ridge.predict(X_poly), y))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2393.4141681620827, tolerance: 0.5437699671168931
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2401.0207544895184, tolerance: 0.5437699671168931
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=4.85524e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2398.509302229874, tolerance: 0.5437699671168931
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=2.07137e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2394.2311041150297, tolerance: 0.5437699671168931
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=9.24146e-21): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2389.6101181683453, tolerance: 0.5437699671168931
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=2.902e-22): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2385.2837390724653, tolerance: 0.5437699671168931
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2381.6786396209627, tolerance: 0.5437699671168931
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2378.911136071691, tolerance: 0.5437699671168931
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2376.9731325940907, tolerance: 0.5437699671168931
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2375.71973982767, tolerance: 0.5437699671168931
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2375.0041292318374, tolerance: 0.5437699671168931
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2374.683530581867, tolerance: 0.5437699671168931
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2374.6167828731554, tolerance: 0.5437699671168931
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2374.654659312588, tolerance: 0.5437699671168931
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2374.645976010666, tolerance: 0.5437699671168931
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2374.432203407713, tolerance: 0.5437699671168931
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2373.8459784622273, tolerance: 0.5437699671168931
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2372.729193671044, tolerance: 0.5437699671168931
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2370.946122960154, tolerance: 0.5437699671168931
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2368.3930462749995, tolerance: 0.5437699671168931
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2365.0051687314626, tolerance: 0.5437699671168931
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2360.7652928633183, tolerance: 0.5437699671168931
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2355.702660404134, tolerance: 0.5437699671168931
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2349.870603562665, tolerance: 0.5437699671168931
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2343.3432070015615, tolerance: 0.5437699671168931
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2336.2172067455363, tolerance: 0.5437699671168931
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2328.605183431131, tolerance: 0.5437699671168931
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2320.627745025084, tolerance: 0.5437699671168931
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2312.4055762704343, tolerance: 0.5437699671168931
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2304.053830478884, tolerance: 0.5437699671168931
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2295.6680236395136, tolerance: 0.5437699671168931
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2287.33392292054, tolerance: 0.5437699671168931
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2279.1081244603615, tolerance: 0.5437699671168931
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2271.0655374837183, tolerance: 0.5437699671168931
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2263.2620651740804, tolerance: 0.5437699671168931
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2255.7359482410357, tolerance: 0.5437699671168931
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2248.5249679943927, tolerance: 0.5437699671168931
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2241.6406468047, tolerance: 0.5437699671168931
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2235.111144384683, tolerance: 0.5437699671168931
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2228.9412740552175, tolerance: 0.5437699671168931
#   model = cd_fast.enet_coordinate_descent(

# %%
import pandas as pd
from pandas import DataFrame
data = {"poly_range":poly_range, "lr_rmse":rmse_lr_list, 
        "lasso_rmse":rmse_lasso_list,"ridge_rmse":rmse_ridge_list}
df = DataFrame(data).set_index("poly_range")
df
# Out:
#              lr_rmse  lasso_rmse  ridge_rmse
# poly_range
# 10          1.902214    2.292292    1.926580
# 11          1.894115    2.293940    1.907888
# 12          1.633644    2.293741    1.906805
# 13          1.339727    2.293033    1.878500
# 14          1.325650    2.291788    1.628606
# 15          0.910677    2.290379    1.475562
# 16          0.718787    2.289048    1.483327
# 17          0.689530    2.287949    1.293848
# 18          0.710138    2.287122    0.887625
# 19          0.732164    2.286560    0.767130
# 20          0.653497    2.286250    0.756400
# 21          0.627405    2.286170    0.614314
# 22          0.536304    2.286289    0.526058
# 23          0.598821    2.286585    0.520693
# 24          0.962645    2.287051    0.509192
# 25          1.141657    2.287666    1.814174
# 26          1.214223    2.288413    2.306236
# 27          1.262938    2.289281    1.895677
# 28          1.316658    2.290265    1.544771
# 29          1.336367    2.291365    1.426140
# 30          1.317599    2.292588    1.534324
# 31          1.277604    2.293944    1.387300
# 32          1.692086    2.295446    3.951857
# 33          1.644145    2.297112    1.531804
# 34          1.675581    2.298958    1.456619
# 35          1.705327    2.300998    1.960347
# 36          1.677319    2.303242    2.771543
# 37          1.659637    2.305689    1.944160
# 38          1.802425    2.308334    2.116878
# 39          1.627922    2.311162    2.034345
# 40          1.883187    2.314154    2.252067
# 41          1.678997    2.317284    2.013205
# 42          1.714961    2.320524    1.810591
# 43          1.705938    2.323832    2.965852
# 44          1.866990    2.327168    1.849281
# 45          1.685437    2.330493    1.866440
# 46          1.793221    2.333771    1.894778
# 47          1.818926    2.336968    1.742346
# 48          1.749953    2.340045    2.018426
# 49          1.821090    2.342971    1.862474

# %%
plt.plot(poly_range, df["ridge_rmse"], label="ridge")
plt.plot(poly_range, df["lr_rmse"], label="lr")
plt.plot(poly_range, df["lasso_rmse"], label="lasso")
plt.legend()
plt.show()

# %%
df.min()
# Out:
# lr_rmse       0.536304
# lasso_rmse    2.286170
# ridge_rmse    0.509192
# dtype: float64

# %%
df["ridge_rmse"].sort_values().head()
# Out:
# poly_range
# 24    0.509192
# 23    0.520693
# 22    0.526058
# 21    0.614314
# 20    0.756400
# Name: ridge_rmse, dtype: float64

# %%
poly_features = PolynomialFeatures(degree=24)
X_poly = poly_features.fit_transform(X)
ridge = Ridge(fit_intercept=False)
ridge.fit(X_poly,y)
# Out:
# Ridge(fit_intercept=False)

# %%
f_x, f_y = f(1000)
plt.plot(f_x, f_y)
plt.scatter(X.flatten(), y.flatten(), s=3, c="black")
plt.plot(X.flatten(), ridge.predict(X_poly).flatten())
plt.show()
